# %%
import uproot
import awkward as ak
print(uproot.__version__)
print(ak.__version__)
# Out:
# 5.2.2
# 2.6.1

# %%
xc='root://xcache.af.uchicago.edu:1094//'
data_fn = xc + 'root://dcgftp.usatlas.bnl.gov:1094//pnfs/usatlas.bnl.gov/LOCALGROUPDISK/rucio/data18_13TeV/04/9a/DAOD_PHYSLITE.34857549._000001.pool.root.1'
mc_fn= xc + 'root://fax.mwt2.org:1094//pnfs/uchicago.edu/atlaslocalgroupdisk/rucio/mc20_13TeV/c3/e9/DAOD_PHYSLITE.34869306._000001.pool.root.1'

# %%
f=uproot.open(data_fn)
tree=f['CollectionTree;1']

use_forth=True

for key, branch in tree.iteritems(filter_typename="*ElementLink*"):
    print(">>>", key, ">>>", branch)
    try:
        if use_forth:
            branch.interpretation._forth = True
        else:
            branch.interpretation._forth = False
        branch.array() #library="np"
    except Exception as e:
        print(f"Problem with {key}:\n{repr(e)}\n")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\ilija\Documents\tmp\analysis_tests\.venv\Lib\site-packages\fsspec\registry.py:236, in get_filesystem_class(protocol)
#     235 try:
# --> 236     register_implementation(protocol, _import_class(bit["class"]))
#     237 except ImportError as e:
#
# File c:\Users\ilija\Documents\tmp\analysis_tests\.venv\Lib\site-packages\fsspec\registry.py:271, in _import_class(cls, minv)
#     270 s3 = mod == "s3fs"
# --> 271 mod = importlib.import_module(mod)
#     272 if s3 and mod.__version__.split(".") < ["0", "5"]:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2288.0_x64__qbz5n2kfra8p0\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\ilija\Documents\tmp\analysis_tests\.venv\Lib\site-packages\fsspec_xrootd\__init__.py:12
#      11 from ._version import version as __version__
# ---> 12 from .xrootd import XRootDFile, XRootDFileSystem
#      14 __all__ = ("__version__", "XRootDFileSystem", "XRootDFile")
#
# File c:\Users\ilija\Documents\tmp\analysis_tests\.venv\Lib\site-packages\fsspec_xrootd\xrootd.py:18
#      17 from fsspec.spec import AbstractBufferedFile  # type: ignore[import-not-found]
# ---> 18 from XRootD import client  # type: ignore[import-not-found]
#      19 from XRootD.client.flags import (  # type: ignore[import-not-found]
#      20     DirListFlags,
#      21     MkDirFlags,
#    (...)
#      24     StatInfoFlags,
#      25 )
#
# ModuleNotFoundError: No module named 'XRootD'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 f=uproot.open(data_fn)
#       2 tree=f['CollectionTree;1']
#       4 use_forth=True
#
# File c:\Users\ilija\Documents\tmp\analysis_tests\.venv\Lib\site-packages\uproot\reading.py:141, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     132 if not isinstance(file_path, str) and not (
#     133     hasattr(file_path, "read") and hasattr(file_path, "seek")
#     134 ):
#     135     raise ValueError(
#     136         "'path' must be a string, pathlib.Path, an object with 'read' and "
#     137         "'seek' methods, or a length-1 dict of {file_path: object_path}, "
#     138         f"not {path!r}"
#     139     )
# --> 141 file = ReadOnlyFile(
#     142     file_path,
#     143     object_cache=object_cache,
#     144     array_cache=array_cache,
#     145     custom_classes=custom_classes,
#     146     decompression_executor=decompression_executor,
#     147     interpretation_executor=interpretation_executor,
#     148     **options,
#     149 )
#     151 if object_path is None:
#     152     return file.root_directory
#
# File c:\Users\ilija\Documents\tmp\analysis_tests\.venv\Lib\site-packages\uproot\reading.py:559, in ReadOnlyFile.__init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     554 self.hook_before_create_source()
#     556 source_cls, file_path = uproot._util.file_path_to_source_class(
#     557     file_path, self._options
#     558 )
# --> 559 self._source = source_cls(file_path, **self._options)
#     561 self.hook_before_get_chunks()
#     563 if self._options["begin_chunk_size"] < _file_header_fields_big.size:
#
# File c:\Users\ilija\Documents\tmp\analysis_tests\.venv\Lib\site-packages\uproot\source\fsspec.py:31, in FSSpecSource.__init__(self, file_path, **options)
#      29 def __init__(self, file_path: str, **options):
#      30     super().__init__()
# ---> 31     self._fs, self._file_path = fsspec.core.url_to_fs(
#      32         file_path, **self.extract_fsspec_options(options)
#      33     )
#      35     # What should we do when there is a chain of filesystems?
#      36     self._async_impl = self._fs.async_impl
#
# File c:\Users\ilija\Documents\tmp\analysis_tests\.venv\Lib\site-packages\fsspec\core.py:383, in url_to_fs(url, **kwargs)
#     372 known_kwargs = {
#     373     "compression",
#     374     "encoding",
#    (...)
#     380     "num",
#     381 }
#     382 kwargs = {k: v for k, v in kwargs.items() if k not in known_kwargs}
# --> 383 chain = _un_chain(url, kwargs)
#     384 inkwargs = {}
#     385 # Reverse iterate the chain, creating a nested target_* structure
#
# File c:\Users\ilija\Documents\tmp\analysis_tests\.venv\Lib\site-packages\fsspec\core.py:332, in _un_chain(path, kwargs)
#     330 for bit in reversed(bits):
#     331     protocol = kwargs.pop("protocol", None) or split_protocol(bit)[0] or "file"
# --> 332     cls = get_filesystem_class(protocol)
#     333     extra_kwargs = cls._get_kwargs_from_urls(bit)
#     334     kws = kwargs.pop(protocol, {})
#
# File c:\Users\ilija\Documents\tmp\analysis_tests\.venv\Lib\site-packages\fsspec\registry.py:238, in get_filesystem_class(protocol)
#     236         register_implementation(protocol, _import_class(bit["class"]))
#     237     except ImportError as e:
# --> 238         raise ImportError(bit["err"]) from e
#     239 cls = registry[protocol]
#     240 if getattr(cls, "protocol", None) in ("abstract", None):
#
# ImportError: Unable to load filesystem from EntryPoint(name='root', value='fsspec_xrootd:XRootDFileSystem', group='fsspec.specs')
